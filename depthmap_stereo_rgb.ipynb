# %% [markdown]
# <a href="https://colab.research.google.com/github/iuri/opencv/blob/main/depthmap_stereo_rgb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# How do I extract depth from an image?
# How do we estimate depth? Our eyes estimate depth by comparing the image obtained by our left and right eye. The minor displacement between both viewpoints is enough to calculate an approximate depth map. We call the pair of images obtained by our eyes a stereo pair.
#
# if so, I must use 2 cameras to simulate such scenario.
# What's the left camera? and what's the right one?

# %% [markdown]
# References
# https://docs.opencv.org/3.4/dd/d53/tutorial_py_depthmap.html
#
# https://ez.analog.com/depth-perception-ranging-technologies/lidar-solutions/3d-tof-depth-sensing/f/q-a/561113/how-to-get-a-valid-depth-map-in-python
#
# https://github.com/analogdevicesinc/aditof_sdk/blob/master/bindings/python/examples/first_frame/first_frame.py
#
# https://li-chongyi.github.io/proj_SR.html
#
#
# https://answers.opencv.org/question/185947/how-to-resolve-a-sadwindowsize-error/
#
#
# https://medium.com/yodayoda/from-depth-map-to-point-cloud-7473721d3f

# %%
import os
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt


from PIL import Image

# to mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')

import pandas as pd
pd.set_option('display.max_columns', None)
# Out:
# Mounted at /content/gdrive

# %%
# import dataset
df = pd.read_csv(
      '/content/gdrive/MyDrive/MCTI/Bolsa/dataset_skeleton.csv', index_col=0
)

# %%
df.count()
# Out:
# mark1_c1_y    3762
# mark2_c1_x    3760
# mark2_c1_y    3760
# mark3_c1_x    3735
# mark3_c1_y    3735
# mark4_c1_x    3452
# mark4_c1_y    3452
# mark1_c2_x    3762
# mark1_c2_y    3762
# mark2_c2_x    3760
# mark2_c2_y    3760
# mark3_c2_x    3757
# mark3_c2_y    3757
# mark4_c2_x    3701
# mark4_c2_y    3701
# mark1_c3_x    3762
# mark1_c3_y    3762
# mark2_c3_x    3749
# mark2_c3_y    3749
# mark3_c3_x    3704
# mark3_c3_y    3704
# mark4_c3_x    3459
# mark4_c3_y    3459
# dtype: int64

# %%
df
# Out:
#             mark1_c1_y  mark2_c1_x  mark2_c1_y  mark3_c1_x  mark3_c1_y  \
# mark1_c1_x
# 232                 47       237.0       201.0       240.0       351.0
# 232                 47       237.0       200.0       240.0       351.0
# 232                 47       237.0       201.0       240.0       351.0
# 232                 46       235.0       198.0       238.0       347.0
# 233                 48       235.0       202.0       236.0       352.0
# ...                ...         ...         ...         ...         ...
# 230                 27       229.0       150.0       226.0       296.0
# 240                 17       273.0       121.0       329.0       271.0
# 286                 98       372.0       234.0       357.0       356.0
# 243                 13       290.0       123.0       357.0       240.0
# 241                 30       275.0       150.0       318.0       269.0
#
#             mark4_c1_x  mark4_c1_y  mark1_c2_x  mark1_c2_y  mark2_c2_x  \
# mark1_c1_x
# 232              233.0       497.0         281          92       291.0
# 232              233.0       497.0         281          92       291.0
# 232              234.0       497.0         281          92       291.0
# 232              231.0       501.0         281          91       289.0
# 233              229.0       496.0         281          93       289.0
# ...                ...         ...         ...         ...         ...
# 230              190.0       407.0         280          61       273.0
# 240              290.0       392.0         278          94       265.0
# 286                NaN         NaN         277          95       262.0
# 243              350.0       336.0         273          66       240.0
# 241              298.0       367.0         273          66       241.0
#
#             mark2_c2_y  mark3_c2_x  mark3_c2_y  mark4_c2_x  mark4_c2_y  \
# mark1_c1_x
# 232              236.0       296.0       387.0       203.0       509.0
# 232              236.0       296.0       387.0       204.0       509.0
# 232              236.0       296.0       388.0       204.0       509.0
# 232              234.0       290.0       388.0       198.0       511.0
# 233              237.0       291.0       389.0       306.0       527.0
# ...                ...         ...         ...         ...         ...
# 230              184.0       249.0       276.0       251.0       283.0
# 240              236.0       249.0       296.0       251.0       304.0
# 286              238.0       251.0       312.0       275.0       368.0
# 243              193.0       195.0       291.0       196.0       372.0
# 241              187.0        35.0        17.0       192.0       293.0
#
#             mark1_c3_x  mark1_c3_y  mark2_c3_x  mark2_c3_y  mark3_c3_x  \
# mark1_c1_x
# 232                265         123       274.0       256.0       282.0
# 232                265         123       273.0       256.0       282.0
# 232                265         123       273.0       256.0       282.0
# 232                266         122       278.0       255.0       291.0
# 233                264         123       274.0       255.0       283.0
# ...                ...         ...         ...         ...         ...
# 230                268          98       282.0       180.0       315.0
# 240                259          87       249.0       154.0       206.0
# 286                261          87       251.0       154.0       201.0
# 243                271          76       290.0       131.0       283.0
# 241                270          76       129.0        12.0       288.0
#
#             mark3_c3_y  mark4_c3_x  mark4_c3_y
# mark1_c1_x
# 232              397.0       292.0       527.0
# 232              397.0       291.0       527.0
# 232              397.0       292.0       527.0
# 232              396.0       303.0       527.0
# 233              396.0       293.0       529.0
# ...                ...         ...         ...
# 230              307.0       377.0       400.0
# 240              290.0       215.0       454.0
# 286              301.0       182.0       487.0
# 243              432.0       414.0       450.0
# 241              131.0       332.0       291.0
#
# [3762 rows x 23 columns]

# %%
# Comparing an image and its neighboor of the same camera.
# Left image paths
pathL = '/content/gdrive/MyDrive/MCTI/dataset/camera1/new/'
# Right image paths
pathR = '/content/gdrive/MyDrive/MCTI/dataset/camera1/new/'
print(os.listdir(pathL))
print(os.listdir(pathR))
# Potential fix 
# os.environ['OPENCV_IO_MAX_IMAGE_PIXELS']=str(2**64)

filenameL = pathL + '0021.png'
filenameR = pathR + '0022.png'
# Out:
# ['0085.png', '1288.png', '2636.png', '3312.png', '0052.png', '1505.png', '2965.png', '2018.png', '0046.png', '1539.png', '2554.png', '2024.png', '1713.png', '1908.png', '1707.png', '1934.png', '2742.png', '0250.png', '2568.png', '2030.png', '2756.png', '1061.png', '2597.png', '3110.png', '1075.png', '3448.png', '0278.png', '0287.png', '2583.png', '3104.png', '0244.png', '1920.png', '0293.png', '2540.png', '3105.png', '2233.png', '1048.png', '1935.png', '0279.png', '0292.png', '1060.png', '2582.png', '1712.png', '1074.png', '3139.png', '2541.png', '2596.png', '3111.png', '3138.png', '2569.png', '2555.png', '1706.png', '1049.png', '2226.png', '2232.png', '2227.png', '0286.png', '2743.png', '2019.png', '2031.png', '1921.png', '0090.png', '3313.png', '1909.png', '1289.png', '3475.png', '3461.png', '1510.png', '3449.png', '0084.png', '1276.png', '3307.png', '1262.png', '1538.png', '0251.png', '0245.png', '2780.png', '2757.png', '1504.png', '2025.png', '2958.
2152.png', '3258.png', '0078.png', '2973.png', '3476.png', '0050.png', '3304.png', '0044.png', '1329.png', '1513.png', '1315.png', '3310.png', '3462.png', '2783.png', '2967.png', '2344.png', '2378.png', '1473.png', '1881.png', '1659.png', '0118.png', '3270.png', '2191.png', '3264.png', '0124.png', '2813.png', '1467.png', '0130.png', '2608.png', '1117.png', '2436.png', '1895.png', '2350.png', '2422.png', '2807.png', '2185.png', '1498.png', '1301.png', '1671.png', '3066.png', '2486.png', '2451.png', '3029.png', '2393.png', '1819.png', '1164.png', '1856.png', '1842.png', '3015.png', '2492.png', '1831.png', '2445.png', '0326.png', '1825.png', '0332.png', '2337.png', '3099.png', '1158.png', '2387.png', '1103.png', '3072.png', '1665.png', '0341.png', '2323.png', '1428.png', '2848.png', '1366.png', '3217.png', '2135.png', '2874.png', '1372.png', '2860.png', '2653.png', '2479.png', '1399.png', '14 ...

# %%
# reading images as RGB returns an error in the retrieve proecdure, disparity.
imgL = cv.imread(filenameL)
imgR = cv.imread(filenameR)

# %%
plt.imshow(imgL)
plt.show()

# %%
if imgL == 'None' or imgR == 'None':
  print("Image's empty!")
  print("Shapes: ", imgL.shape, imgR.shape)
# Out:
# <ipython-input-10-15ee6467e16e>:1: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if imgL == 'None' or imgR == 'None':

# %%
imgR.size
# Out:
# 921600

# %%
imgR.shape
# Out:
# (640, 480, 3)

# %%
stereo = cv.StereoBM_create(numDisparities=16, blockSize=15)
print(stereo)
# Out:
# < cv2.StereoBM 0x7fcd5c2e25b0>

# %%
disparity = stereo.compute(imgL,imgR)
print(disparity.size)
print(disparity.shape)
print(disparity)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-14-6e8b1df7c7d7> in <module>
# ----> 1 disparity = stereo.compute(imgL,imgR)
#       2 print(disparity.size)
#       3 print(disparity.shape)
#       4 print(disparity)
#
# error: OpenCV(4.6.0) /io/opencv/modules/calib3d/src/stereobm.cpp:1173: error: (-210:Unsupported format or combination of formats) Both input images must have CV_8UC1 in function 'compute'

# %%
plt.imshow(disparity,'gray')
# plt.imshow(disparity)
plt.show()

# %%
# Disparity from Cameras 1 and 3

# %%
print(disparity)
# Out:
# [[-16 -16 -16 ... -16 -16 -16]
#  [-16 -16 -16 ... -16 -16 -16]
#  [-16 -16 -16 ... -16 -16 -16]
#  ...
#  [-16 -16 -16 ... -16 -16 -16]
#  [-16 -16 -16 ... -16 -16 -16]
#  [-16 -16 -16 ... -16 -16 -16]]

# %%
# Left image paths
pathL = '/content/gdrive/MyDrive/MCTI/dataset/camera1/new/'
# Right image paths
pathR = '/content/gdrive/MyDrive/MCTI/dataset/camera3/new/'
print(os.listdir(pathL))
print(os.listdir(pathR))

# Potential fix 
# os.environ['OPENCV_IO_MAX_IMAGE_PIXELS']=str(2**64)

filenameL = pathL + '0001.png'
filenameR = pathR + '0001.png'
# Out:
# ['0085.png', '1288.png', '2636.png', '3312.png', '0052.png', '1505.png', '2965.png', '2018.png', '0046.png', '1539.png', '2554.png', '2024.png', '1713.png', '1908.png', '1707.png', '1934.png', '2742.png', '0250.png', '2568.png', '2030.png', '2756.png', '1061.png', '2597.png', '3110.png', '1075.png', '3448.png', '0278.png', '0287.png', '2583.png', '3104.png', '0244.png', '1920.png', '0293.png', '2540.png', '3105.png', '2233.png', '1048.png', '1935.png', '0279.png', '0292.png', '1060.png', '
png', '3128.png', '0421.png', '2236.png', '2550.png', '1059.png', '0347.png', '1918.png', '2587.png', '0390.png', '1930.png', '3699.png', '1924.png', '0384.png', '2593.png', '1515.png', '3302.png', '3464.png', '1273.png', '1267.png', '0179.png', '3470.png', '3316.png', '1501.png', '2008.png', '2020.png', '1529.png', '0637.png', '0151.png', '2746.png', '2752.png', '3458.png', '0145.png', '0623.png', '2034.png', '2975.png', '0810.png', '2961.png', '0804.png', '2785.png', '0192.png', '1298.png', '0186.png', '2949.png', '0838.png', '2791.png', '1461.png', '2168.png', '1307.png', '3510.png', '3276.png', '0019.png', '3504.png', '1313.png', '3262.png', '1475.png', '2154.png', '0743.png', '0025.png', '2632.png', '3538.png', '2626.png', '0031.png', '0757.png', '1449.png', '0964.png', '2140.png', '2815.png', '2801.png', '0970.png', '0958.png', '0780.png', '3289.png', '2197.png', '2829.png', '2183.png', '0794.png', '1105.png', '3712.png', '1663.png', '3074.png', '1677.png', '0569.png', '3060.png', '2418.png', '3706.png', '2430.png', '1111.png', '1139.png', '1887.png', '0227.png', '0541.png', '2342.png', '3048.png', '1893.png', '0555.png', '0233.png', '2424.png', '1844.png', '0582.png', '1878.png', '2395.png', '1850.png', '0596.png', '1688.png', '2381.png', '1868.png', '2385.png', '1854.png', '1698.png', '0592.png', '1840.png', '0586.png', '2391.png', '1115.png', '37 ...

# %%
imgL = cv.imread(filenameL, cv.IMREAD_GRAYSCALE)
imgR = cv.imread(filenameR, cv.IMREAD_GRAYSCALE)

print(imgL)
# print(imgR)
# Out:
# [[ 54  54  56 ... 169 165 171]
#  [ 57  55  56 ... 168 173 172]
#  [ 59  56  55 ... 169 169 170]
#  ...
#  [ 30  31  30 ...  29  27  26]
#  [ 30  30  30 ...  28  27  25]
#  [ 31  31  31 ...  29  27  25]]

# %%
# cv.imshow(window_name, imgL)
# cv.imshow(window_name, imgR)
if imgL == 'None' or imgR == 'None':
  print("Image's empty!")
  print("Shapes: ", imgL.shape, imgR.shape)
# Out:
# <ipython-input-39-5b1ad68629a6>:3: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if imgL == 'None' or imgR == 'None':

# %%
stereo = cv.StereoBM_create(numDisparities=16, blockSize=15)
print(stereo)
# Out:
# < cv2.StereoBM 0x7ff81d52c7d0>

# %%
disparity = stereo.compute(imgL,imgR)
print(disparity.size)
print(disparity.shape)
print(disparity)
# Out:
# 307200
# (640, 480)
# [[-16 -16 -16 ... -16 -16 -16]
#  [-16 -16 -16 ... -16 -16 -16]
#  [-16 -16 -16 ... -16 -16 -16]
#  ...
#  [-16 -16 -16 ... -16 -16 -16]
#  [-16 -16 -16 ... -16 -16 -16]
#  [-16 -16 -16 ... -16 -16 -16]]

# %%
plt.imshow(disparity,'gray')
# plt.imshow(disparity)
plt.show()

# %%
# !pip install aditofpython

import aditofpython as tof
import numpy as np

system = tof.System()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement aditofpython (from versions: none)
# ERROR: No matching distribution found for aditofpython
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-f7dbd85a603c> in <module>
#       1 get_ipython().system('pip install aditofpython')
#       2
# ----> 3 import aditofpython as tof
#       4 import numpy as np
#       5
#
# ModuleNotFoundError: No module named 'aditofpython'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Depth
depthImage = np.array(frame.getData(tof.FrameDataType.Depth), copy=False)
depthImage = depthImage[0: frameDetails.height, 0: frameDetails.width]
print(depthImage)
